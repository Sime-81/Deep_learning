# %% [markdown]
# # Matplotlib les graphique important
#
# Dans nos code de machine learning nous pouvons avoir besoin de manipuler des data-sets très différent des un des autres ce qui veux aussi dire qu'il faut les afficher de manière différente voila pourquoi je vais vous siter les Graphique important de Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
name = list(iris.target_names)

print(f"x contient {x.shape[0]} exemples et {x.shape[1]} variable")
print(f"il y a {np.unique(y).size} classes")
x
# Out:
# x contient 150 exeples et 4 variable
# il y a 3 classes
# ['setosa', 'versicolor', 'virginica']

# %% [markdown]
# ## (5) Graphique de Classification avec plt.scatter
#
# ici nous utilisons une base de donnée sur les fleur de lisse représenter par x 4 colone de 150 ligne de donné et y de 150 données répartie entre 0 et 2. ici un graphique linéaire n'est pas très pertinent alors nous utiliseront un graphique scatter pour représenter nos donnée en nuage de point.

# %%
plt.scatter(x[:, 0], x[:, 1], c=y, alpha=0.7, s=70) #expliquation des différen paramètre si dessous
plt.xlabel('longueur sépale')
plt.ylabel('largeur sépale')
# Out:
# Text(0, 0.5, 'largeur sépale')

# %% [markdown]
# Le paramétre [c] fixer sur y nous permet de changer la couleur des point cela nous permet de classifier les point des donnée y {0, 1, 2} pour mieux visualiser. Le paramétre [Alpha] nous permet de controler la transparence des points. Le paramètre [s] nous permet de controler la taille des point.
#
# ____
#
# Pourquoi me diriez vous n'utilison nous pas un graphique linéaire avec [.plot] mais je peux vous lassurer vous ne vous poserez plus la question avce la démonstration suivante qui vous montrera le résulta du type de graphique linéaire.

# %%
plt.plot(x[:, 0], x[:, 1])
plt.xlabel('longueur sépale')
plt.ylabel('largeur sépale')
# Out:
# Text(0, 0.5, 'largeur sépale')

# %% [markdown]
# Pas mal on dirait un gribouillage d'un enfant de 5 ans mais trêve de plaisenterie vous venez de constatez pourquoi il est intérésent de changer de type de graphique pour montrer d'autre méthode d'affichage.

# %% [markdown]
# ## (4) Graphique 3D
#
# Nous allons voir comment afficher un graphique en 3D ce qui nous permettra d'afficher la casi totaliter de notre base de donnée

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=y)

# %% [markdown]
# Pour voir la version 3D navigable vous puvez utiliser le script [3dGraphique(1).py]

# %% [markdown]
# Ici nous pouvons voir un nuage de point en 3d. Malgré que nous devions utiliser la version orienter objet de matplotlib elle est très puissante et très utile mais voyons voire comment elle se comporte pour afficher des fonction mathèmatique

# %%
f = lambda x, y: np.sin(x) + np.cos(x + y)

# %%
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')

# %% [markdown]
# Ici nous avons modéliser un fonction en 3d je sais que les ligne de code paraisse complexe mais nous avons juste modéliser les ax pour permettre l'affichage de la fonction. l'argument [cmap] control la couleur de se graphuiqe et nous avons utiliser plot_surface pour ce rendu.

# %% [markdown]
# ## (3) Histogramme
#
# Souvant nous aurons besoin de visualiser de manière claire l'écart type et la moyen et quoi de mieux qu'un histogramme.

# %%
plt.hist(x[:,0])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Ici la colonne des y reprèsente le nombre de fois ou une donné est répétter et l'axe des x la longueur du sépale. se graphique est très praitique pour visualiser le regroupement des individus

# %%
plt.hist(x[:, 0], bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# l'argument bins nous permets de controler le nombre de colonne que nous voulons afficher (au plus il y en à au plus le graphique est précis)

# %%
plt.hist(x[:, 0], bins=20)
plt.hist(x[:, 1], bins=20)
# Out:
# (array([ 1.,  3.,  4.,  3.,  8., 14., 14., 10., 26., 11., 19., 12.,  6.,
#          4.,  9.,  2.,  1.,  1.,  1.,  1.]),
#  array([2.  , 2.12, 2.24, 2.36, 2.48, 2.6 , 2.72, 2.84, 2.96, 3.08, 3.2 ,
#         3.32, 3.44, 3.56, 3.68, 3.8 , 3.92, 4.04, 4.16, 4.28, 4.4 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Nous pouvons afficher deux packs de donné différent dans le même graphique

# %%
plt.hist2d(x[:, 0], x[:, 1], cmap='Blues')
plt.xlabel('longueur sépale')
plt.ylabel('largeur sépale')
plt.colorbar()

# %% [markdown]
# Nous pouvons afficer ce graphique en 2D ce qui nous permet de rentrer 2 donnés différent ce qui est plus pertinent pour la classification que celui d'avant. Avec [plt.colorbar()] nous affichons la barre de couleur qui nous permets de comprendre le graphique. L'argument [cmap] controle la couleur du graphique.

# %% [markdown]
# Mais ce type de graphique nous permet ausse de traiter une image en noire et blanc pour en faire une analyse

# %%
from scipy import misc
face =misc.face(gray=True)
plt.imshow(face, cmap='gray')

# %%
plt.hist(face.ravel(), bins=255)
plt.show()

# %% [markdown]
# Ceci nous permet de faire une analyse sur qu'elle sont les couleur de pixel qui revienne le plus.

# %% [markdown]
# ## (2) Contour plots
#
# Ce type de graphique est super utile quand nous voulons visualiser un model qui occupe 3 dimension en vu du dessu. En intelligence artificielle nous cherchons souvent à maximiser une fonction, ce type de graphique vous permetra une meilleur compréhention de ce que vous essayer de maximiser.
#
# Nous allons réutiliser la fonction que nous avons fait passer en 3D

# %%
plt.contour(X, Y, Z, 20, colors='black')

# %% [markdown]
# L'argument 20 est utiliser pour la présition des couche au plus le nombre est grand au plus c'est précis. l'argument [colors] nous permets de changer la couleur du graphique pour adapter à la lisibiliter souhaiter.

# %% [markdown]
# Je vais écrire une fonction plus complexe qui vous permetra de mieux comprendre à quel point ce type de graphique est pratique (les ligne c'est positifs et les pointier négatif)

# %%
f = lambda x, y: np.sin(x) + np.cos(x + y)*np.cos(x)

X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
plt.contour(X, Y, Z, 20, colors='black')

# %% [markdown]
# Nous pouvons utiliser un autre type de contour plot pour visualiser ce graphique de manière différente

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# Ce graphique nous permet de comprendre quel sont les valeur de nos différent graphique de manière plus visuel

# %% [markdown]
# ## (1) Imshow
#
# Nous permets d'afficher des image mais ne limitons pas ce graphique à ceci il nous permet de faire énorément de chose. des graphique de corrélation, analyser des problèmes d'optimisation, visualiser un masque avant de s'en servir dans du booléan indexing  et beaucoup d'autre graphique de visualisation.
#
# ____
#
# Par exemple nous allons tracer notre graphique de corélation pour notre data set des fleur d'iris

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()
plt.show()

# %% [markdown]
# On pourrait parler longtemps de Imshow mais on va juste s'intérésser à une fonction d'optimisation qu'on à fait plutôt pour la visualiser avec Imshow.

# %%
plt.figure(figsize=(12, 8))
plt.imshow(Z)

# %% [markdown]
# ## Excercice
#
# utiliser le code de l'excercice de la doc Matplotlib_1 pour afficher nos quatre variable du data set de l'iris sur un seul et même figure.

# %%
datasets = {f"data_iris{i + 1}" : x[:, i] for i in range(4)}

def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 18))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
    
    plt.show()

# %%
graphique(datasets)

# %% [markdown]
# ### Correction de cette excercice
#
# je n'ai appliquer le code exactement comme voulu j'aurais du rester sur scatter. ce que je dois retenir est de ne pas fermer mon esprit sur ce genre d'exercice.

# %%
n = x.shape[1] #récupére le nombre de colonne de x
plt.figure(figsize=(12, 10)) #création de la figure et set de sa taille 
for i in range(n): #création d'un boucle qui s'éxécutera le nombre de colonne du datasets
    plt.subplot(n//2, n//2, i+1) #fonction subplot pour travailler sur plussier graphique diviser en n//2 ligne et n//2 colonne i+1 car il n'y a pas de graphique 0
    plt.scatter(x[:, 0], x[:, i], c=y) #création du graphique scatter avec pour base la colonne 0 comparer au autre colonne
    plt.xlabel('colonne 0')
    plt.ylabel(f'colonne {i}')
    plt. colorbar(ticks=list(np.unique(y))) #permet d'afficher la légende des couleur
    
plt.show()
